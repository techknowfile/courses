# %%
import zipfile
import os, glob, sys, re
sys.dont_write_bytecode = True

curr_dir = os.getcwd()
ORIGINAL_SUBMISSIONS = "original_submissions/"
SUBMISSIONS = "submissions/"

def unzip_original_submissions():
    student_folders = []
    for file in glob.glob(ORIGINAL_SUBMISSIONS + "*.zip"):
        file_name = os.path.splitext(os.path.basename(file))[0]
        rel_path = SUBMISSIONS + file_name
        zip_file = zipfile.ZipFile(file, 'r')
        zip_file.extractall(rel_path)
        student_folders.append(rel_path)
    return student_folders
        
def moveFilesToTestFolder(student_folder, test_files):
    import shutil
    # Delete tmp folder
    if os.path.exists("tmp"):
        for file in test_files:
            if os.path.exists("tmp/"+file):
                os.remove("tmp/"+file)
            if os.path.exists("tmp/"+file+'c'):
                os.remove("tmp/"+file+'c')
                        
    # Copy student files
    for dirpath, dirnames, filenames in os.walk(student_folder):
        for filename in [f for f in filenames if f in test_files]:
            shutil.copy(os.path.join(dirpath, filename), "tmp/" + filename)
            
def runAutograder():
    import subprocess, re
    os.chdir("tmp")
    proc = subprocess.Popen(['python2', 'autograder.py', '--mute', 'True'], stdout=subprocess.PIPE)
    tmp = proc.stdout.read()
    grades = re.search("Provisional grades(.*)\nYour", tmp, flags=re.DOTALL)
    result = None
    if grades:
        result = grades.group(1)
    os.chdir("../")
    return result
    
def main():
    student_folders = unzip_original_submissions()
    for student_folder in student_folders:
        tmp = student_folder.split('_')
        sid = tmp[1]
        attempt = tmp[3]
        print sid, attempt,
        moveFilesToTestFolder(student_folder, ["search.py", "searchAgents.py"])
        grades = runAutograder()
        total_grade = None
        if grades:
            total_grade = re.search("Total: (.*)", grades).group(1)
        print grades
 
if __name__ == '__main__':
    main()
# Out:
# adeotale 2017-09-14-18-29-23
# ==================
# Question q1: 3/3
# Question q2: 3/3
# Question q3: 3/3
# Question q4: 3/3
# Question q5: 0/3
# Question q6: 0/3
# Question q7: 0/4
# Question q8: 0/3
# ------------------
# Total: 12/25
#
# jcamou1 2017-09-15-10-39-25
# ==================
# Question q1: 3/3
# Question q2: 3/3
# Question q3: 3/3
# Question q4: 3/3
# Question q5: 0/3
# Question q6: 0/3
# Question q7: 0/4
# Question q8: 0/3
# ------------------
# Total: 12/25
#
# sbhand12 2017-09-14-11-22-22
# ==================
# Question q1: 3/3
# Question q2: 3/3
# Question q3: 3/3
# Question q4: 3/3
# Question q5: 0/3
# Question q6: 0/3
# Question q7: 0/4
# Question q8: 0/3
# ------------------
# Total: 12/25
#
# drdavis8 2017-09-07-21-08-10
# ==================
# Question q1: 3/3
# Question q2: 3/3
# Question q3: 3/3
# Question q4: 3/3
# Question q5: 0/3
# Question q6: 0/3
# Question q7: 0/4
# Question q8: 0/3
# ------------------
# Total: 12/25
#
# cdave1 2017-09-07-10-55-27
# ==================
# Question q1: 0/3
# Question q2: 0/3
# Question q3: 3/3
# Question q4: 3/3
# Question q5: 0/3
# Question q6: 0/3
# Question q7: 0/4
# Question q8: 0/3
# ------------------
# Total: 6/25
#
# mebaker7 2017-09-14-13-56-44
# ==================
# Question q1: 3/3
# Question q2: 3/3
# Question q3: 3/3
# Question q4: 3/3
# Question q5: 0/3
# Question q6: 0/3
# Question q7: 0/4
# Question q8: 0/3
# ------------------
# Total: 12/25
#
# kvbhatt1 2017-09-15-09-18-20
# ==================
# Question q1: 3/3
# Question q2: 3/3
# Question q3: 3/3
# Question q4: 3/3
# Question q5: 0/3
# Question q6: 0/3
# Question q7: 0/4
# Question q8: 0/3
# ------------------
# Total: 12/25
#
# adeotale 2017-09-14-18-29-23
# ==================
# Question q1: 3/3
# Question q2: 3/3
# Question q3: 3/3
# Question q4: 0/3
# Question q5: 0/3
# Question q6: 0/3
# Question q7: 0/4
# Question q8: 0/3
# ------------------
# Total: 9/25
#
# udasu 2017-09-13-14-14-40
# ==================
# Question q1: 3/3
# Question q2: 3/3
# Question q3: 3/3
# Question q4: 3/3
# Question q5: 0/3
# Question q6: 0/3
# Question q7: 0/4
# Question q8: 0/3
# ------------------
# Total: 12/25
#
# lkdecker 2017-09-12-14-43-15 None
# zdeng17 2017-09-15-12-23-37
# ==================
# Question q1: 3/3
# Question q2: 3/3
# Question q3: 3/3
# Question q4: 3/3
# Question q5: 0/3
# Question q6: 0/3
# Question q7: 0/4
# Question q8: 0/3
# ------------------
# Total: 12/25
#
# sbidve 2017-09-14-21-48-17
# ==================
# Question q1: 3/3
# Question q2: 3/3
# Question q3: 3/3
# Question q4: 3/3
# Question q5: 0/3
# Question q6: 0/3
# Question q7: 0/4
# Question q8: 0/3
# ------------------
# Total: 12/25
#
# racohn 2017-09-11-17-05-54
# ==================
# Question q1: 3/3
# Question q2: 3/3
# Question q3: 3/3
# Question q4: 3/3
# Question q5: 0/3
# Question q6: 0/3
# Question q7: 0/4
# Question q8: 0/3
# ------------------
# Total: 12/25
#
# mbommir1 2017-09-15-08-45-10
# ==================
# Question q1: 3/3
# Question q2: 3/3
# Question q3: 3/3
# Question q4: 3/3
# Question q5: 0/3
# Question q6: 0/3
# Question q7: 0/4
# Question q8: 0/3
# ------------------
# Total: 12/25
#
# tdandala 2017-09-15-00-18-19
# ==================
# Question q1: 3/3
# Question q2: 3/3
# Question q3: 3/3
# Question q4: 3/3
# Question q5: 0/3
# Question q6: 0/3
# Question q7: 0/4
# Question q8: 0/3
# ------------------
# Total: 12/25

# %%
main()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-58ca95c5b364> in <module>()
# ----> 1 main()
#
# NameError: name 'main' is not defined

# %%
print "hello"
